# %%
import pandas as pd
matches = pd.read_csv("matches_2023_2021.csv", index_col=0)
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W   3   1
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 1        Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3  Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4  Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5         Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6       West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
#
#   season             team
# 1   2023  Manchester City
# ...

# %%
matches.shape
# Out:
# (1520, 28)

# %%
matches["team"].value_counts()
# Out:
# team
# Manchester City             76
# Crystal Palace              76
# Nottingham Forest           76
# Brentford                   76
# Everton                     76
# Wolverhampton Wanderers     76
# Fulham                      76
# Arsenal                     76
# Brighton and Hove Albion    76
# Bournemouth                 76
# West Ham United             76
# Manchester United           76
# Newcastle United            76
# Chelsea                     76
# Tottenham Hotspur           76
# Aston Villa                 76
# Liverpool                   76
# Luton Town                  38
# Burnley                     38
# Sheffield United            38
# Leicester City              38
# Leeds United                38
# Southampton                 38
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result  gf  ga  \
# 1   2022-08-06  12:30  Premier League   Matchweek 1  Sat  Away      D   2   2
# 2   2022-08-15  20:00  Premier League   Matchweek 2  Mon  Home      D   1   1
# 3   2022-08-22  20:00  Premier League   Matchweek 3  Mon  Away      L   1   2
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   9   0
# 5   2022-08-31  20:00  Premier League   Matchweek 5  Wed  Home      W   2   1
# ..         ...    ...             ...           ...  ...   ...    ...  ..  ..
# 53  2024-04-24  20:00  Premier League  Matchweek 29  Wed  Away      L   0   2
# 54  2024-04-27  12:30  Premier League  Matchweek 35  Sat  Away      D   2   2
# 55  2024-05-05  16:30  Premier League  Matchweek 36  Sun  Home      W   4   2
# 56  2024-05-13  20:00  Premier League  Matchweek 37  Mon  Away      D   3   3
# 57  2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      W   2   0
#
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 30    40
# Matchweek 23    40
# Matchweek 24    40
# Matchweek 25    40
# Matchweek 18    40
# Matchweek 26    40
# Matchweek 27    40
# Matchweek 28    40
# Matchweek 31    40
# Matchweek 2     40
# Matchweek 32    40
# Matchweek 33    40
# Matchweek 29    40
# Matchweek 35    40
# Matchweek 36    40
# Matchweek 37    40
# Matchweek 34    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 20    40
# Matchweek 19    40
# Matchweek 3     40
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 6     40
# Matchweek 7     40
# Matchweek 8     40
# Matchweek 9     40
# Matchweek 10    40
# Matchweek 11    40
# Matchweek 12    40
# Matchweek 13    40
# Matchweek 14    40
# Matchweek 15    40
# Matchweek 16    40
# Matchweek 17    40
# Matchweek 38    40
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf                 int64
# ga                 int64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
del matches["comp"]
del matches["notes"]
matches["date"] = pd.to_datetime(matches["date"])
matches["target"] = (matches["result"] == "W").astype("int")
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 1  2023-08-11  20:00   Matchweek 1  Fri  Away      W   3   0          Burnley
# 3  2023-08-19  20:00   Matchweek 2  Sat  Home      W   1   0    Newcastle Utd
# 4  2023-08-27  14:00   Matchweek 3  Sun  Away      W   2   1    Sheffield Utd
# 5  2023-09-02  15:00   Matchweek 4  Sat  Home      W   5   1           Fulham
# 6  2023-09-16  15:00   Matchweek 5  Sat  Away      W   3   1         West Ham
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 42 2023-04-30  14:00  Matchweek 34  Sun  Away      L   1   3    Newcastle Utd
# 43 2023-05-08  20:00  Matchweek 35  Mon  Away      L   3   4  Nott'ham Forest
# 44 2023-05-13  15:00  Matchweek 36  Sat  Home      L   0   2           Fulham
# 45 2023-05-21  14:00  Matchweek 37  Sun  Away      L   1   3         Brighton
# 46 2023-05-28  16:30  Matchweek 38  Sun  Home      D   4   4        Liverpool
#
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 1  2023-08-11  20:00   Matchweek 1  Fri  Away      W   3   0          Burnley
# 3  2023-08-19  20:00   Matchweek 2  Sat  Home      W   1   0    Newcastle Utd
# 4  2023-08-27  14:00   Matchweek 3  Sun  Away      W   2   1    Sheffield Utd
# 5  2023-09-02  15:00   Matchweek 4  Sat  Home      W   5   1           Fulham
# 6  2023-09-16  15:00   Matchweek 5  Sat  Away      W   3   1         West Ham
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 42 2023-04-30  14:00  Matchweek 34  Sun  Away      L   1   3    Newcastle Utd
# 43 2023-05-08  20:00  Matchweek 35  Mon  Away      L   3   4  Nott'ham Forest
# 44 2023-05-13  15:00  Matchweek 36  Sat  Home      L   0   2           Fulham
# 45 2023-05-21  14:00  Matchweek 37  Sun  Away      L   1   3         Brighton
# 46 2023-05-28  16:30  Matchweek 38  Sun  Home      D   4   4        Liverpool
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(class_weight={0: 1, 1: 2},n_estimators=100, min_samples_split=40, random_state=33)
train = matches[matches["date"] < '2023-08-08']
test = matches[matches["date"] > '2023-09-08']
predictors = ["venue_code", "opp_code", "hour", "day_code"]
rf.fit(train[predictors], train["target"])
RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)
preds = rf.predict(test[predictors])
from sklearn.metrics import accuracy_score
error = accuracy_score(test["target"], preds)
error

error
# Out:
# 0.5381231671554252

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          199  217
# 1           98  168

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds)
# Out:
# 0.43636363636363634

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Manchester City").sort_values("date")
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 4  2022-08-27  15:00   Matchweek 4  Sat  Home      W   4   2   Crystal Palace
# 5  2022-08-31  19:30   Matchweek 5  Wed  Home      W   6   0  Nott'ham Forest
# 6  2022-09-03  17:30   Matchweek 6  Sat  Away      D   1   1      Aston Villa
# 9  2022-09-17  12:30   Matchweek 8  Sat  Away      W   3   0           Wolves
# 10 2022-10-02  14:00   Matchweek 9  Sun  Home      W   6   3   Manchester Utd
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 51 2024-04-28  16:30  Matchweek 35  Sun  Away      W   2   0  Nott'ham Forest
# 52 2024-05-04  17:30  Matchweek 36  Sat  Home      W   5   1           Wolves
# 53 2024-05-11  12:30  Matchweek 37  Sat  Away      W   4   0           Fulham
# 54 2024-05-14  20:00  Matchweek 34  Tue  Away      W   2   0        Tottenham
# 55 2024-05-19  16:00  Matchweek 38  Sun  Home      W   3   1         West Ham
#
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                                  date   time         round  day venue result  \
# team
# Arsenal                 3  2022-08-27  17:30   Matchweek 4  Sat  Home      W
#                         4  2022-08-31  19:30   Matchweek 5  Wed  Home      W
#                         5  2022-09-04  16:30   Matchweek 6  Sun  Away      L
#                         7  2022-09-18  12:00   Matchweek 8  Sun  Away      W
#                         8  2022-10-01  12:30   Matchweek 9  Sat  Home      W
# ...                               ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 40 2024-04-24  19:45  Matchweek 29  Wed  Home      L
#                         41 2024-04-27  15:00  Matchweek 35  Sat  Home      W
#                         42 2024-05-04  17:30  Matchweek 36  Sat  Away      L
#                         43 2024-05-11  15:00  Matchweek 37  Sat  Home      L
#                         44 2024-05-19  16:00  Matchweek 38  Sun  Away      L
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 3  2022-08-27  17:30   Matchweek 4  Sat  Home      W   2   1           Fulham
# 4  2022-08-31  19:30   Matchweek 5  Wed  Home      W   2   1      Aston Villa
# 5  2022-09-04  16:30   Matchweek 6  Sun  Away      L   1   3   Manchester Utd
# 7  2022-09-18  12:00   Matchweek 8  Sun  Away      W   3   0        Brentford
# 8  2022-10-01  12:30   Matchweek 9  Sat  Home      W   3   1        Tottenham
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 40 2024-04-24  19:45  Matchweek 29  Wed  Home      L   0   1      Bournemouth
# 41 2024-04-27  15:00  Matchweek 35  Sat  Home      W   2   1       Luton Town
# 42 2024-05-04  17:30  Matchweek 36  Sat  Away      L   1   5  Manchester City
# 43 2024-05-11  15:00  Matchweek 37  Sat  Home      L   1   3   Crystal Palace
# 44 2024-05-19  16:00  Matchweek 38  Sun  Away      L   0   2        Liverpool
#
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-08-08']
    test = data[data["date"] > '2023-09-08']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    a_error = accuracy_score(test["target"], preds)

    return combined, error,a_error
combined, error,a_error = make_predictions(matches_rolling, predictors + new_cols)
error,a_error
# Out:
# (0.47911547911547914, 0.5850439882697948)
